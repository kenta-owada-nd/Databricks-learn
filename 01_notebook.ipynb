# %% [markdown]
# <img src="./nttdata_logo" width="200">

# %% [markdown]
# # ノートブックの基本
#
# ノートブックは、Databricksでコードを対話的に開発および実行する主要な手段です。このレッスンでは、Databricksノートブックの使用方法について基本的な紹介を提供します。
#
# ## 学習目標
# このレッスンの最後までに、以下のことができるようになるはずです。
# * ノートブックでセルを作成・実行する
# * ノートブックの言語を設定する
# * マジックコマンドを説明し、使用する
# * SQLセルを作成および実行する
# * Pythonセルを作成および実行する
# * マークダウンセルを作成する
# * 別のノートブックを実行する

# %% [markdown]
# ## セルの作成・実行
#
# ノートブックはセルごとのコードの実行を提供します。ノートブックでは複数の言語を混在させることができます。ユーザーはコードを強化するためにプロット、画像、およびマークダウンテキストを追加できます。
#
# このコース全体で、私たちのノートブックは学習用のツールとして設計されています。ノートブックはDatabricksで本番コードとして簡単に展開できるだけでなく、データの探索、レポート作成、ダッシュボード作成のための強力なツールセットも提供します。
#
# ### セルの作成
# * セルを作成するには、セルの境目にある**code**、**Text**、**Assistant**のいずれかをクリックします。
#
# ### セルの実行
# * 以下のセルを実行するには、次のいずれかのオプションを使用します：
#   * **CTRL+ENTER**または**CTRL+RETURN**
#   * セルを実行して次のセルに移動するために**SHIFT+ENTER**または**SHIFT+RETURN**を使用します
#   * **Run Cell**、**Run All Above**、または**Run All Below**を使用します

# %%
print("I'm running Python!")

# %% [markdown]
# **注意**: セルごとのコードの実行は、セルが複数回実行されたり、順序が逆になったりすることを意味します。明示的に指示されていない限り、このコースのノートブックは常に上から下に向けて一つのセルずつ実行されることを前提としてください。エラーが発生した場合、トラブルシューティングを試みる前にセルの前後のテキストを読み、エラーが意図的な学習の瞬間でないか確認してください。ほとんどのエラーは、ノートブック内で見落とされた以前のセルを実行するか、トップから全体のノートブックを再実行することで解決できます。

# %% [markdown]
# ### デフォルトのノートブック言語の設定
#
# 上記のセルは、ノートブックのデフォルト言語がPythonに設定されているため、Pythonコマンドを実行します。
#
# DatabricksノートブックはPython、SQL、Scala、およびRをサポートしています。ノートブックの作成時に言語を選択できますが、いつでも変更できます。
#
# デフォルトの言語は、ページの上部にあるノートブックのタイトルの右側に表示されます。このコースでは、SQLとPythonのノートブックを組み合わせて使用します。
#
# このノートブックのデフォルト言語をSQLに変更します。
#
# 手順:
# * 画面上部のノートブックタイトルの横にある **Python** をクリックします
# * ポップアップ画面で、ドロップダウンリストから **SQL** を選択します
#
# **注意**: ちょうどこのセルの前に、新しい行が <strong><code>&#37;python</code></strong> と表示されるはずです。これについては後で説明します。

# %% [markdown]
# ## マジックコマンド
# * マジックコマンドは、Databricksノートブックに固有のものです
# * 他のノートブック製品で見られるマジックコマンドに似ています
# * これらは、ノートブックの言語に関係なく同じ結果を提供する組み込みコマンドです
# * セルの先頭に単一のパーセント（%）記号があると、それはマジックコマンドを識別します
#   * セルごとに1つのマジックコマンドしか使用できません
#   * マジックコマンドはセル内で最初に指定する必要があります

# %% [markdown]
# ### 言語マジック
# 言語マジックコマンドは、ノートブックのデフォルト言語以外の言語でコードを実行できるようにします。このコースでは、以下の言語マジックを見ていきます：
# * <strong><code>&#37;python</code></strong>
# * <strong><code>&#37;sql</code></strong>
#
# 現在設定されているノートブックのタイプに対して言語マジックを追加する必要はありません。
#
# 上記でノートブックの言語をPythonからSQLに変更した際、既存のPythonで書かれたセルには<strong><code>&#37;python</code></strong>コマンドが追加されました。
#
# **注意**: ノートブックのデフォルト言語を頻繁に変更する代わりに、デフォルトの主要言語を維持し、他の言語でコードを実行する必要がある場合にのみ言語マジックを使用すべきです。

# %%
# %sql
SELECT "SQLを実行しています！"

# %% [markdown]
# ### Markdown
#
# マジックコマンド **&percnt;md** は、セル内でマークダウンを表示することを可能にします：
# * このセルをダブルクリックして編集を開始します
# * 編集を終了するには **`Esc`** キーを押します
#
# # タイトル1
# ## タイトル2
# ### タイトル3
#
# これは緊急放送システムのテストです。これはテストです。
#
# これは **太字** の単語を含むテキストです。
#
# これは *斜体* の単語を含むテキストです。
#
# これは順序付きリストです
# 1. 1つ
# 1. 2つ
# 1. 3つ
#
# これは順不同リストです
# * りんご
# * 桃
# * バナナ
#
# そしてもちろん、テーブルもあります：
#
# | 名前   | 値    |
# |--------|-------|
# | Yi     | 1     |
# | Ali    | 2     |
# | Selina | 3     |

# %% [markdown]
# ### %run
# * 別のノートブックから **%run** マジックコマンドを使用してノートブックを実行できます
# * 実行するノートブックは相対パスで指定されます
# * 参照されたノートブックは、呼び出し元のノートブックから実行されるため、一時的なビューやその他のローカルな宣言は呼び出し元のノートブックから利用できます

# %%
# %run ./00_command

# %%
print(f"Hello {company}")
